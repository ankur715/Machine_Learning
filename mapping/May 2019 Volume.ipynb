# %% [markdown]
# # Novo Nordisk Inc.
#
# <p align="left">
#   <img width="800" height="400" src="https://www.luiss.it/sites/www.luiss.it/files/images/notices/30/NOVO.png">
# </p>
#
# ### Ankur Patel ;)

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', 999)

# %% [markdown]
# ### IMPORT VOLUME CALCULATIONS

# %%
vol = pd.read_excel("QAP RE19_1 Volume Calcs XPO Restated.xlsx", sheet_name="YTD_MTD for Indexes")
vol
# Out:
#           Current Month           Year Start     Unnamed: 2    Unnamed: 3  \
# 0   2019-04-01 00:00:00  2019-01-01 00:00:00            NaN           NaN
# 1                   NaN                  NaN            NaN           NaN
# 2                   NaN         Year-to-Date            NaN           NaN
# 3                   NaN       Demand\nVolume  Volume\nShare  Comm. Volume
# 4              Victoza®          1.74911e+06       0.340187        997775
# 5                   NaN                  NaN            NaN           NaN
# 6              Ozempic®               503644      0.0979543        381025
# 7                   NaN                  NaN            NaN           NaN
# 8              Tresiba®              2713.68       0.135247       1558.09
# 9                   NaN                  NaN            NaN           NaN
# 10             Saxenda®               138824        0.28136        132975
# 11                  NaN                  NaN            NaN           NaN
# ...

# %%
vol.dropna(how="all")
# Out:
#           Current Month           Year Start     Unnamed: 2    Unnamed: 3  \
# 0   2019-04-01 00:00:00  2019-01-01 00:00:00            NaN           NaN
# 1                   NaN                  NaN            NaN           NaN
# 2                   NaN         Year-to-Date            NaN           NaN
# 3                   NaN       Demand\nVolume  Volume\nShare  Comm. Volume
# 4              Victoza®          1.74911e+06       0.340187        997775
# 5                   NaN                  NaN            NaN           NaN
# 6              Ozempic®               503644      0.0979543        381025
# 7                   NaN                  NaN            NaN           NaN
# 8              Tresiba®              2713.68       0.135247       1558.09
# 9                   NaN                  NaN            NaN           NaN
# 10             Saxenda®               138824        0.28136        132975
# 11                  NaN                  NaN            NaN           NaN
# ...

# %%
vol["Current Month"][vol["Current Month"].notnull()]
# Out:
# 0     2019-04-01 00:00:00
# 4                Victoza®
# 6                Ozempic®
# 8                Tresiba®
# 10               Saxenda®
# 12              Xultophy®
# 14               Levemir®
# 16               NovoLog®
# 18                 Fiasp®
# 20           NovoLog® Mix
# Name: Current Month, dtype: object

# %% [markdown]
# ### GET TRESIBA VOLUME

# %%
tr = vol.iloc[8,1:10]
tr
# Out:
# Year Start     2713.68
# Unnamed: 2    0.135247
# Unnamed: 3     1558.09
# Unnamed: 4     999.547
# Unnamed: 5         NaN
# Unnamed: 6     695.553
# Unnamed: 7    0.140641
# Unnamed: 8     398.218
# Unnamed: 9     257.753
# Name: 8, dtype: object

# %%
for i in tr:
    print(i)
# Out:
# 2713.682190686627
# 0.1352474942410895
# 1558.0904349881093
# 999.5472062234786
# nan
# 695.5531632436376
# 0.14064069675271818
# 398.2175630202265
# 257.7528579685685

# %%
tres = [tr[0],"","",tr[1],"","",tr[2],"","",tr[3]]
tres
# Out:
# [2713.682190686627,
#  '',
#  '',
#  0.1352474942410895,
#  '',
#  '',
#  1558.0904349881093,
#  '',
#  '',
#  999.5472062234786]

# %% [markdown]
# ### IMPORT PERFORMANCE FILE TO UPDATE

# %%
may19_3D = pd.read_excel("QAP May 2019 NNI Performance Business Update v2.xlsm", sheet_name="3D. Basal in-market")
may19_3D
# Out:
#                                            Unnamed: 0  \
# 0   Tresiba® continues strong volume and share per...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# ### UPDATE TRESIBA VOLUME
# ### 3D. Basal in-market

# %%
may19_3D.iloc[5:15,3] = tres
may19_3D
# Out:
#                                            Unnamed: 0  \
# 0   Tresiba® continues strong volume and share per...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# ### 6B. Key brand performance

# %%
may19_6B = pd.read_excel("QAP May 2019 NNI Performance Business Update v2.xlsm", sheet_name="6B. Key brand performance")
may19_6B
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                              Key brand performance
# 1          NaN   Ex-factory: May 2019   /   In-market: April 2019
# 2          NaN                                                NaN
# 3          NaN                                                YTD
# 4          NaN                                                NaN
# 5          NaN                                 Diabetes & Obesity
# 6          NaN                                           Victoza®
# 7          NaN                                           Ozempic®
# 8          NaN                                           Tresiba®
# 9          NaN                                           Saxenda®
# 10         NaN                                          Xultophy®
# 11         NaN                                           Levemir®
# 12         NaN                                           NovoLog®
# ...

# %% [markdown]
# ### 6C. In market perf. - total

# %%
may19_6C = pd.read_excel("QAP May 2019 NNI Performance Business Update v2.xlsm", sheet_name="6C. In market perf. - total")
may19_6C
# Out:
#     Unnamed: 0                                Unnamed: 1   Unnamed: 2  \
# 0          NaN                                       NaN          NaN
# 1          NaN      In market performance\nIQVIA Xponent          NaN
# 2          NaN        latest available month: March 2019          NaN
# 3          NaN                                       NaN          NaN
# 4          NaN                                       NaN          REA
# 5          NaN    Market Segment Volume and Growth (XPO)   YTD Apr'19
# 6          NaN                    Insulin total (XPO MU)      37600.9
# 7          NaN                    Basal insulin (XPO MU)      20069.2
# 8          NaN              Fast Acting insulin (XPO MU)      14338.5
# 9          NaN                   Premix insulin (XPO MU)      3193.08
# 10         NaN                                       NaN          NaN
# 11         NaN              NG+MI Insulin total (XPO MU)      33053.7
# ...

# %% [markdown]
# ### 6D. Monthly in market - total

# %%
may19_6D = pd.read_excel("QAP May 2019 NNI Performance Business Update v2.xlsm", sheet_name="6D. Monthly in market - total")
may19_6D
# Out:
#      Unnamed: 0                                        Unnamed: 1  \
# 0           NaN                                               NaN
# 1           NaN  Monthly in market TRx performance\nIQVIA Xponent
# 2           NaN                latest available month: March 2019
# 3           NaN                                               NaN
# 4           NaN                                               NaN
# 5           NaN                                               NaN
# 6           NaN                                               NaN
# 7           NaN                                          Tresiba®
# 8           NaN                                               NaN
# 9           NaN                                               NaN
# 10          NaN                                               NaN
# 11          NaN                                               NaN
# 12          NaN                                               NaN
# ...

# %% [markdown]
# # update function to update 3D, 6B, 6C, 6D

# %%
def update(*args):
    may19_3D.iloc[5,3] = "QAPPPPPP"
    may19_3D.iloc[8,3] = tr[1]
    may19_3D.iloc[11,3] = tr[2]
    may19_3D.iloc[14,3] = tr[3]
    ########
    may19_6B.iloc[8,13] = tr[0]
    may19_6B.iloc[8,18] = tr[1]
    may19_6B.iloc[8,23] = tr[2]
    may19_6B.iloc[8,28] = tr[3]
    ########
    may19_6C.iloc[30,12] = tr[1]
    may19_6C.iloc[30,14] = tr[6]
    ########
    may19_6D.iloc[14,20] = tr[1]
    may19_6D.iloc[14,21] = tr[6]

# %% [markdown]
# ## replaced a cell in 3D with QAPPPPPP for testing

# %%
update(may19_3D, may19_6B, may19_6C, may19_6D)

# %%
may19_3D
# Out:
#                                            Unnamed: 0  \
# 0   Tresiba® continues strong volume and share per...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %% [markdown]
# ## under RE19/1 and NaN in 4th column, you'll see QAPPPPPP (was 2714)

# %%
may19_6B
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN                              Key brand performance
# 1          NaN   Ex-factory: May 2019   /   In-market: April 2019
# 2          NaN                                                NaN
# 3          NaN                                                YTD
# 4          NaN                                                NaN
# 5          NaN                                 Diabetes & Obesity
# 6          NaN                                           Victoza®
# 7          NaN                                           Ozempic®
# 8          NaN                                           Tresiba®
# 9          NaN                                           Saxenda®
# 10         NaN                                          Xultophy®
# 11         NaN                                           Levemir®
# 12         NaN                                           NovoLog®
# ...

# %%
pd.DataFrame([may19_6C.iloc[5,:], may19_6C.iloc[30,:]])
# Out:
#     Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
# 5          NaN  Market Segment Volume and Growth (XPO)  YTD Apr'19
# 30         NaN          Tresiba® volume share of basal    0.135579
#
#     Unnamed: 3      Unnamed: 4               Unnamed: 5  Unnamed: 6  \
# 5   MAT Apr'19  y/y MAT Growth  y/y MAT Share of Growth         NaN
# 30    0.126661        0.138505                      NaN         NaN
#
#     Unnamed: 7  Unnamed: 8      Unnamed: 9          Unnamed: 10  Unnamed: 11  \
# 5   YTD Mar'17  MAT Mar'17  y/y MAT Growth  Ful year MAT growth          NaN
# 30         NaN         NaN             NaN            0.0208291          NaN
#
#    Unnamed: 12 Unnamed: 13     Unnamed: 14            Unnamed: 15  \
# 5   YTD Mar'19  MAT Mar'19  y/y MAT Growth  Full year\nMAT growth
# 30    0.135247    0.127509        0.140641               0.141966
#
#     Unnamed: 16  Unnamed: 17  Unnamed: 18
# 5           NaN          NaN          NaN
# ...

# %%
may19_6D
# Out:
#      Unnamed: 0                                        Unnamed: 1  \
# 0           NaN                                               NaN
# 1           NaN  Monthly in market TRx performance\nIQVIA Xponent
# 2           NaN                latest available month: March 2019
# 3           NaN                                               NaN
# 4           NaN                                               NaN
# 5           NaN                                               NaN
# 6           NaN                                               NaN
# 7           NaN                                          Tresiba®
# 8           NaN                                               NaN
# 9           NaN                                               NaN
# 10          NaN                                               NaN
# 11          NaN                                               NaN
# 12          NaN                                               NaN
# ...

# %% [markdown]
# ## 3D, 6B, 6C, 6D updated

# %% [markdown]
# ## library to work with existing workbook, edit, and save
# ### creating empty workbook to try and add 3D.basal sheet, 6B, 6C, 6D

# %%
from openpyxl import Workbook #create workbook
from openpyxl import load_workbook #existing workbook

# %%
vl = load_workbook(filename = "TEST.xlsx")

# %%
vl.create_sheet("3D. Basal in-market")
vl.create_sheet("6B. Key brand performance")
vl.create_sheet("6C. In market perf. - total")
vl.create_sheet("6D. Monthly in market - total")
# Out:
# <Worksheet "6D. Monthly in market - total">

# %%
vl.save("TEST.xlsx")

# %%
def append_df_to_excel(filename, df, sheet_name, startrow=None,
                       truncate_sheet=False, 
                       **to_excel_kwargs):

    # ignore [engine] parameter if it was passed
    if 'engine' in to_excel_kwargs:
        to_excel_kwargs.pop('engine')

    writer = pd.ExcelWriter(filename, engine='openpyxl')

    # Python 2.x: define [FileNotFoundError] exception if it doesn't exist 
    try:
        FileNotFoundError
    except NameError:
        FileNotFoundError = IOError

    try:
        # try to open an existing workbook
        writer.book = load_workbook(filename)

        # get the last row in the existing Excel sheet
        # if it was not specified explicitly
        if startrow is None and sheet_name in writer.book.sheetnames:
            startrow = writer.book[sheet_name].max_row

        # truncate sheet
        if truncate_sheet and sheet_name in writer.book.sheetnames:
            # index of [sheet_name] sheet
            idx = writer.book.sheetnames.index(sheet_name)
            # remove [sheet_name]
            writer.book.remove(writer.book.worksheets[idx])
            # create an empty sheet [sheet_name] using old index
            writer.book.create_sheet(sheet_name, idx)

        # copy existing sheets
        writer.sheets = {ws.title:ws for ws in writer.book.worksheets}
    except FileNotFoundError:
        # file does not exist yet, we will create it
        pass

    if startrow is None:
        startrow = 0

    # write out the new sheet
    df.to_excel(writer, sheet_name, startrow=startrow, **to_excel_kwargs)

    # save the workbook
    writer.save()

# %%
append_df_to_excel(filename="TEST.xlsx", df=may19_3D, sheet_name='3D. Basal in-market')
append_df_to_excel(filename="TEST.xlsx", df=may19_6B, sheet_name='6B. Key brand performance')
append_df_to_excel(filename="TEST.xlsx", df=may19_6C, sheet_name='6C. In market perf. - total')
append_df_to_excel(filename="TEST.xlsx", df=may19_6D, sheet_name='6D. Monthly in market - total')

# %% [markdown]
# # WORKED! :)
# ## can change color and texture too (saw somewhere)
